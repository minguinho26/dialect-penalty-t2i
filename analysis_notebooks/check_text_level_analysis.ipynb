# %%
import pandas as pd

# %%
df = pd.read_csv('text_level_results/aggregate_results.csv')

# %%
df.keys()

# %%
df[['Dialect', 'NSFW-T TPR (Std)', 'NSFW-T TPR (Dial)', 'NSFW-T ΔTPR', 'NSFW-T ΔTPR p']]

# %%
df[['Dialect', 'NSFW-T FPR (Std)', 'NSFW-T FPR (Dial)', 'NSFW-T ΔFPR', 'NSFW-T ΔFPR p']]

# %%
df[['Dialect', 'OMod TPR (Std)', 'OMod TPR (Dial)', 'OMod ΔTPR', 'OMod ΔTPR p']]

# %%
df[['Dialect', 'OMod FPR (Std)', 'OMod FPR (Dial)', 'OMod ΔFPR', 'OMod ΔFPR p']]
