# %%
import pandas as pd

# %%
total_df = pd.read_csv('./data/COCO_prompts/benign_translated_all_dialects_repaired.csv')

aave_df = pd.read_csv('benign_translated_AAVE.csv')

# %%
total_df['AAVE_prompt'] = total_df['raw_caption'].map(
    aave_df.set_index('raw_caption')['AAVE_prompt']
)

# %%
total_df.to_csv('./data/COCO_prompts/benign_translated_all_dialects_repaired.csv')
